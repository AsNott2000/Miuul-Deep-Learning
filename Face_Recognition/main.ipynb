# %%
# !pip install deepface

# %%
images_path = '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture'
img_path = '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face11.png'

# %%
from deepface import DeepFace
import os
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #**Age Detection**

# %%
DeepFace.analyze(img_path = img_path, actions=['age'])
# Out:
# [{'age': 25,
#   'region': {'x': 280,
#    'y': 410,
#    'w': 1391,
#    'h': 1391,
#    'left_eye': (1230, 948),
#    'right_eye': (692, 942)},
#   'face_confidence': 0.91}]

# %%
result = DeepFace.analyze(img_path = img_path, actions=['age'])

# %%
#resmi karsimiza getirme

def visualize_attribute(img_path, result, attribute = "age"):
  image = cv2.imread(img_path)
  image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  if attribute in result[0]:

    prediction = result[0][attribute]

    text = f"{attribute}: {prediction}"
  else:
    text = f"{attribute}: not found result"

  font = cv2.FONT_HERSHEY_SIMPLEX
  font_scale = 1.5
  thickness = 2
  color = (255,255,255)
  shadow_color = (0,0,0)

  plt.imshow(image_rgb)
  plt.axis('off')
  plt.title(text)
  plt.show()

# %%
visualize_attribute(img_path, result, attribute = "age")

# %%
#tum resimlere ulasma
image_paths = [os.path.join(images_path, f) for f in os.listdir(images_path) if f.endswith(('.jpg','.jpeg','.png'))]

# %%
image_paths
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face11.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face13.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face15.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face14.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face12.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face16.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face17.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face18.png',
#  '/content/drive/MyDrive/Colab Notebooks/Deep_Learning/Face_recognition/faces_lecture/face19.png',
# ...

# %%
for path in image_paths:
  result = DeepFace.analyze(path, actions = ['age'])
  visualize_attribute(path, result)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #**Gender Detection**

# %%
DeepFace.analyze(img_path = img_path, actions=['gender'])
# Out:
# 24-09-04 21:03:34 - gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:04<00:00, 119MB/s]
# [{'gender': {'Woman': 47.429150342941284, 'Man': 52.57084369659424},
#   'dominant_gender': 'Man',
#   'region': {'x': 280,
#    'y': 410,
#    'w': 1391,
#    'h': 1391,
#    'left_eye': (1230, 948),
#    'right_eye': (692, 942)},
#   'face_confidence': 0.91}]

# %%
result = DeepFace.analyze(img_path = img_path, actions=['gender'])

# %%
visualize_attribute(img_path, result , 'gender')

# %%
for path in image_paths:
  result = DeepFace.analyze(path, actions = ['gender'])
  visualize_attribute(path, result, "gender")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #**Race Detection**

# %%
for path in image_paths:
  result = DeepFace.analyze(path, actions = ['race'])
  visualize_attribute(path, result,"dominant_race")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #**Emotion**

# %%
DeepFace.analyze(img_path = img_path, actions = ['emotion'])
# Out:
# 24-09-04 21:17:11 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 87.1MB/s]
# [{'emotion': {'angry': 4.7260036290510945e-05,
#    'disgust': 4.2865483826208495e-07,
#    'fear': 0.03461031179863968,
#    'happy': 99.87572433045813,
#    'sad': 0.004938805571019544,
#    'surprise': 0.06448436574638,
#    'neutral': 0.02018501304911294},
#   'dominant_emotion': 'happy',
#   'region': {'x': 280,
#    'y': 410,
#    'w': 1391,
#    'h': 1391,
#    'left_eye': (1230, 948),
#    'right_eye': (692, 942)},
#   'face_confidence': 0.91}]

# %%
result = DeepFace.analyze(path, actions = ['emotion'])

# %%
for path in image_paths:
  result = DeepFace.analyze(path, actions = ['emotion'])
  visualize_attribute(path, result,"dominant_emotion")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
